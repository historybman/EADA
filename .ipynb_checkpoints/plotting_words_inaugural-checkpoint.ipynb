# 19         Abraham Lincoln  \n\nThe Avalon Project : Second Inaugural Addr...
# 20        Ulysses S. Grant  \n\n\n\n\r\n\r\n\r\nFirst Inaugural Address of...
# 21        Ulysses S. Grant  \n\n\n\n\r\n\r\n\r\nSecond Inaugural Address o...
# 22     Rutherford B. Hayes  \n\n\n\n\r\n\r\n\r\nInaugural Address of Ruthe...
# 23       James A. Garfield  This one was funny:http://avalon.law.yale.edu/...
# 24        Grover Cleveland  \n\n\n\n\r\n\r\n\r\nFirst Inaugural Address of...
# 25        Grover Cleveland  \n\n\n\n\r\n\r\n\r\nSecond Inaugural Address o...
# 26       Benjamin Harrison  \n\n\n\n\r\n\r\n\r\nInaugural Address of Benja...
# 27        William McKinley  \n\n\n\n\r\n\r\n\r\nFirst Inaugural Address of...
# 28        William McKinley  \n\n\n\n\r\n\r\n\r\nSecond Inaugural Address o...
# 29      Theodore Roosevelt  \n\n\n\n\r\n\r\n\r\nInaugural Address of Theod...
# 30     William Howard Taft  \n\n\n\n\r\n\r\n\r\nInaugural Address of Willi...
# 31          Woodrow Wilson  \n\n\n\n\r\n\r\n\r\nFirst Inaugural Address of...
# 32          Woodrow Wilson  \n\n\n\n\r\n\r\n\r\nSecond Inaugural Address o...
# 33       Warren G. Harding  \n\n\n\n\r\n\r\n\r\nInaugural Address of Warre...
# 34         Calvin Coolidge  This one was funny:http://avalon.law.yale.edu/...
# 35          Herbert Hoover  \n\n\n\n\r\n\r\n\r\nInaugural Address of Herbe...
# 36   Franklin D. Roosevelt  \n\n\n\n\r\n\r\n\r\nFirst Inaugural Address of...
# 37   Franklin D. Roosevelt  \n\n\n\n\r\n\r\n\r\nSecond Inaugural Address o...
# 38   Franklin D. Roosevelt  \n\n\n\n\r\n\r\n\r\nThird Inaugural Address of...
# 39   Franklin D. Roosevelt  \n\n\n\n\r\n\r\n\r\nFourth Inaugural Address o...
# 40         Harry S. Truman  \n\n\n\n\r\n\r\n\r\nInaugural Address of Harry...
# 41    Dwight D. Eisenhower  \n\n\n\n\r\n\r\n\r\nFirst Inaugural Address of...
# 42    Dwight D. Eisenhower  \n\n\n\n\r\n\r\n\r\nSecond Inaugural Address o...
# 43         John F. Kennedy  \n\n\n\n\r\n\r\n\r\nInaugural Address of John ...
# 44   Lyndon Baines Johnson  \n\n\n\n\r\n\r\n\r\nInaugural Address of Lyndo...
# 45   Richard Milhous Nixon  \n\n\n\n\r\n\r\n\r\nFirst Inaugural Address of...
# 46   Richard Milhous Nixon  \n\n\n\n\r\n\r\n\r\nSecond Inaugural Address o...
# 47            Jimmy Carter  \n\n\n\n\r\n\r\n\r\nInaugural Address of Jimmy...
# 48           Ronald Reagan  \n\n\n\n\r\n\r\n\r\nFirst Inaugural Address of...
# 49           Ronald Reagan  \n\n\n\n\r\n\r\n\r\nSecond Inaugural Address o...
# 50             George Bush  \n\n\n\n\r\n\r\n\r\nInaugural Address of Georg...
# 51         William Clinton  \n\n\n\n\n\n\n\nThe Avalon Project at Yale Law...
# 52         William Clinton  \n\n\n\n\n\n\n\nThe Avalon Project at Yale Law...
# 53          George W. Bush  \n\n\n\n\n\n\n\nThe Avalon Project at Yale Law...
# 54          George W. Bush  \n\n\n\n\n\n\n\nThe Avalon Project at Yale Law...
# 55            Barack Obama  \n\n\n\n\n\n\n\nThe Avalon Project at Yale Law...
#
#     wordcounts
# 0       1443.0
# 1        149.0
# 2       2417.0
# 3       1742.0
# 4       2162.0
# 5       1193.0
# 6       1230.0
# 7       3503.0
# 8       4600.0
# 9       2919.0
# 10      1134.0
# 11      1181.0
# 12         NaN
# 13      8434.0
# 14      4805.0
# 15      1096.0
# 16      3335.0
# 17         NaN
# 18      3770.0
# 19       841.0
# 20      1132.0
# 21      1346.0
# 22      2483.0
# 23         NaN
# 24      1689.0
# 25      2024.0
# 26      4401.0
# 27      3967.0
# 28      2226.0
# 29       992.0
# 30      5438.0
# 31      1709.0
# 32      1536.0
# 33      3336.0
# 34         NaN
# 35      3758.0
# 36      1887.0
# 37      1811.0
# 38      1329.0
# 39       557.0
# 40      2276.0
# 41      2452.0
# 42      1647.0
# 43      1350.0
# 44      1490.0
# 45      2115.0
# 46      1797.0
# 47      1232.0
# 48      2438.0
# 49      2564.0
# 50      2319.0
# 51      1601.0
# 52      2176.0
# 53      1595.0
# 54      2073.0
# 55      2417.0

# %%
inaugurals.plot(kind = 'bar', x = 'years', y = 'wordcounts', color = 'r', figsize=(12,6))
# plt.xticks(np.arange(min('years'), max('years') +1, 16))
# start, end = inaugurals.get_xlim()
# inaugurals.xaxis.set_ticks(np.arange(1780, 2016, 4))
# inaugurals.xaxis.set_ticks(np.arange(min(inaugurals['years']), max(inaugurals['years']), 10)
plt.locator_params(nbins = 10)
# stepsize = (max(inaugurals['years']) - min(inaugurals['years'])) / 6
# ax.plot.xaxis.set_ticks(np.arange(min(inaugurals['years']), max(inaugurals['years']), stepsize))
# plt.xticks([i + 10 for i in range(1780, 2010)])
# years2 = [i for i in range(1780, 2010, 10)]
# plt.xticks(years2)
# plt.axis([1780, 2020, 0, 10000])
# another random try
# ax = plt.gca()
# ax.xaxis.set_major_locator('years')
# another try:
plt.title('Inaugural Addresses')
plt.grid(True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-e63e1465d612> in <module>()
#      15 # ax.xaxis.set_major_locator('years')
#      16 # another try:
# ---> 17 a.set_autoscale_on(False)
#      18 plt.title('Inaugural Addresses')
#      19 plt.grid(True)
#
# NameError: name 'a' is not defined

# %% [markdown]
# ## What's going on above?
# I am not sure why I have an extra index row in the dataframe that I imported from csv. Figure out how to manage that.
#
# And figure out how to spread out the year labels.

# %%
print(type(inaugurals['years'][2]))
# Out:
# <class 'numpy.int64'>
